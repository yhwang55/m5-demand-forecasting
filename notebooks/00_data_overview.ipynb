# %% [markdown]
# # 00 Data Overview
#
# - Sample data loading
# - Basic EDA
# - Seasonality/Promotion signals

# %%
import pandas as pd
from src.data import load_sample_sales, load_sample_calendar, load_sample_prices

sales = load_sample_sales()
calendar = load_sample_calendar()
prices = load_sample_prices()
sales.head()
